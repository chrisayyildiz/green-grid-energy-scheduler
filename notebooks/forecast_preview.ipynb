# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/forecasted_energy_demand.csv", parse_dates=["ds"])
df.set_index("ds")[["yhat", "yhat_lower", "yhat_upper"]].plot(figsize=(15,5), title="Forecasted Energy Demand")
# Out:
# <Axes: title={'center': 'Forecasted Energy Demand'}, xlabel='ds'>
