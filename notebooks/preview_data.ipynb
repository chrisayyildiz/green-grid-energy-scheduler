# %%
import pandas as pd
df = pd.read_csv("../data/simulated_energy_demand.csv", parse_dates=['timestamp'])
df.set_index('timestamp').plot(figsize=(15, 5), title="Simulated Energy Demand")
# Out:
# <Axes: title={'center': 'Simulated Energy Demand'}, xlabel='timestamp'>
